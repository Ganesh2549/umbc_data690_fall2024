# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganesh2549/umbc_data690_fall2024/blob/main/Assignment_06/Assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year   Country  GDP per capita (current US$)  \
# 2722  2009     Niger                    458.421890
# 2723  2010     Niger                    471.612688
# 2054  2006   Lao PDR                    581.010244
# 653   2011  Cameroon                   1497.926585
# 1181  2007   Estonia                  16744.584452
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2722                                57.396000         16037915.0          NER
# 2723                                58.367000         16647543.0          NER
# 2054                                61.493000          5946593.0          LAO
# 653                                 57.133000         20448873.0          CMR
# 1181                                72.814634          1340680.0          EST
#
#                      Region         Income Group    Lending Type
# 2722    Sub-Saharan Africa            Low income             IDA
# ...

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year               Country  GDP per capita (current US$)  \
# 792   2017                 China                   8817.045608
# 2601  2021               Namibia                   4919.188955
# 1646  2016  Hong Kong SAR, China                  43734.198070
# 3696  2014                  Togo                    877.192473
# 2158  2015                 Libya                   7867.515731
#
#       Life expectancy at birth, total (years)
# 792                                 77.248000
# 2601                                59.269000
# 1646                                84.226829
# 3696                                58.853000
# 2158                                71.698000

# %%
df_2022 = df[df["Year"] != 2022]
df_2022.shape
# Out:
# (3906, 9)

# %%
df_2022.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_2022 = df_2022.dropna()
df_2022.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2022.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, GDP per capita (current US$), Life expectancy at birth, total (years), Population, total, Country Code, Region, Income Group, Lending Type]
# Index: []

# %%
df_cleaned = df.drop_duplicates()

print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Cleaned shape: (4123, 9)
#       Year           Country  GDP per capita (current US$)  \
# 758   2021   Channel Islands                  67960.726996
# 1027  2005          Djibouti                    852.890188
# 1114  2016  Egypt, Arab Rep.                   3331.612461
# 837   2005  Congo, Dem. Rep.                    211.572630
# 3681  2018       Timor-Leste                   1241.164485
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 758                                    81.232           172683.0          CHI
# 1027                                   58.316           830861.0          DJI
# 1114                                   70.844         99784030.0          EGY
# 837                                    53.927         56550247.0          COD
# 3681                                   68.017          1261845.0          TLS
#
#                           Region         Income Group    Lending Type
# ...

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2019

df_2019 = df[df["Year"] == year_of_interest]
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (217, 9)
#       Year           Country  GDP per capita (current US$)  \
# 813   2019          Colombia                   6436.509215
# 1117  2019  Egypt, Arab Rep.                   3017.258336
# 3777  2019           Turkiye                   9215.440875
# 3169  2019      Saudi Arabia                  23405.706100
# 4024  2019          Viet Nam                   3491.091410
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 813                                    76.752         50187406.0          COL
# 1117                                   71.358        105618671.0          EGY
# 3777                                   77.832         82579440.0          TUR
# 3169                                   77.304         35827362.0          SAU
# 4024                                   74.093         95776716.0          VNM
#
#                           Region         Income Group    Lending Type
# ...

# %%
df_2019.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               6
# Life expectancy at birth, total (years)    8
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2019 = df_2019.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (203, 9)
#       Year           Country  GDP per capita (current US$)  \
# 851   2019  Congo, Dem. Rep.                    575.882781
# 2713  2019         Nicaragua                   1905.638328
# 3245  2019      Sierra Leone                    506.606914
# 984   2019            Cyprus                  29420.000000
# 2960  2019       Philippines                   3413.849044
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 851                                    60.276         89906890.0          COD
# 2713                                   74.054          6663924.0          NIC
# 3245                                   60.255          8046828.0          SLE
# 984                                    81.397          1228836.0          CYP
# 2960                                   71.865        110380804.0          PHL
#
#                           Region         Income Group    Lending Type
# ...

# %%
fig = px.scatter(
    df_2019,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Compare China, US, India, Russia

# %%
df_4_countries = df_2019[df_2019["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_4_countries.shape)
df_4_countries
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 794   2019               China                  10143.860221
# 1706  2019               India                   2050.163800
# 3074  2019  Russian Federation                  11536.258789
# 3929  2019       United States                  65120.394663
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 794                                 77.968000       1.407745e+09          CHN
# 1706                                70.910000       1.383112e+09          IND
# 3074                                73.083902       1.444063e+08          RUS
# 3929                                78.787805       3.283300e+08          USA
#
#                      Region         Income Group    Lending Type
# 794     East Asia & Pacific  Upper middle income            IBRD
# 1706             South Asia  Lower middle income            IBRD
# ...

# %%
fig = px.scatter(
    df_4_countries,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Compare Wealth and Health of Four Major World Powers {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=55000,  # X coordinate
    y=71,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_quad = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_quad.shape)
df_quad.sample(5)
# Out:
# (76, 9)
#       Year             Country  GDP per capita (current US$)  \
# 3064  2009  Russian Federation                   8562.824219
# 3928  2018       United States                  62823.309438
# 3074  2019  Russian Federation                  11536.258789
# 790   2015               China                   8016.445595
# 3067  2012  Russian Federation                  15420.859375
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3064                                68.684634       1.427853e+08          RUS
# 3928                                78.639024       3.268382e+08          USA
# 3074                                73.083902       1.444063e+08          RUS
# 790                                 76.977000       1.379860e+09          CHN
# 3067                                70.072195       1.432017e+08          RUS
#
#                      Region         Income Group    Lending Type
# ...

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 10/9/20204 Homework Question 1:
#
# for the Quad time series comparison chart above, try to add country name to the end of the line and then remove the color legend.

# %%
import plotly.express as px

# Subset data for selected countries
df_subset = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]

# Plot the data
fig = px.line(
    df_subset,
    x="Year",
    y="GDP per capita (current US$)",
    color="Country",
    labels={
        "Year": "Year",
        "GDP per capita (current US$)": "GDP per Capita (US$)"
    },
    title="GDP per Capita: USA, China, India, Russia"
)

# Annotate the last point for each country
for code in df_subset["Country Code"].unique():
    data = df_subset[df_subset["Country Code"] == code].iloc[-1]
    fig.add_scatter(
        x=[data["Year"]],
        y=[data["GDP per capita (current US$)"]],
        mode="text",
        text=[data["Country"]],
        textposition="middle right",
        showlegend=False
    )

fig.update_layout(showlegend=False, width=850)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_group = df.groupby(["Year", "Region"])["Population, total"].sum().reset_index()
df_group.sample(5)
# Out:
#      Year                      Region  Population, total
# 22   2007       Europe & Central Asia       8.784563e+08
# 10   2005  Middle East & North Africa       3.544624e+08
# 3    2004  Middle East & North Africa       3.470449e+08
# 54   2011                  South Asia       1.684898e+09
# 115  2020  Middle East & North Africa       4.799666e+08

# %% [markdown]
# Home work #5
# Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).
# - 1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.
# - 2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
# - 3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %% [markdown]
# ## Question 1:

# %%
import random

# Select 10 random countries
random_countries = random.sample(list(df["Country"].unique()), 10)

# Filter the DataFrame to include only the selected countries
df_random_countries = df[df["Country"].isin(random_countries)]

# Create a line chart showing the trend of Life Expectancy over time
fig = px.line(
    df_random_countries,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Country",
    title="Life Expectancy Trend for 10 Random Countries",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Question 2

# %%
year_of_interest = 2019

df_random_countries_year = df_random_countries[df_random_countries["Year"] == year_of_interest]

df_random_countries_year = df_random_countries_year.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])

fig = px.scatter(
    df_random_countries_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for 10 Random Countries in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=70000,  # X coordinate
    y=60,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Question 3 : Bonus

# %%
# Group by Year and Region, calculate average GDP per capita, average life expectancy, and total population
df_region_agg = df.groupby(["Year", "Region"]).agg(
    {
        "GDP per capita (current US$)": "mean",
        "Life expectancy at birth, total (years)": "mean",
        "Population, total": "sum"
    }
).reset_index()

df_region_agg.sample(5)
# Out:
#      Year                 Region  GDP per capita (current US$)  \
# 43   2010  Europe & Central Asia                  31303.467052
# 126  2022    East Asia & Pacific                  17520.495539
# 6    2004    Sub-Saharan Africa                    1432.799902
# 104  2018    Sub-Saharan Africa                    2497.289753
# 0    2004    East Asia & Pacific                   9855.982289
#
#      Life expectancy at birth, total (years)  Population, total
# 43                                 76.451081       8.891696e+08
# 126                                      NaN       2.351976e+09
# 6                                  54.742684       7.465468e+08
# 104                                62.542100       1.092404e+09
# 0                                  70.824746       2.094011e+09

# %%
# Create a line chart showing the trend of Life Expectancy over time for all regions
fig = px.line(
    df_region_agg,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Region",
    title="Life Expectancy Trend for All Regions",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Pick a year from the data and create a scatter plot to compare their GDP per capita and life expectancy.
year_of_interest = 2019
df_region_agg_year = df_region_agg[df_region_agg["Year"] == year_of_interest]

fig = px.scatter(
    df_region_agg_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Region",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for All Regions in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
print(df.shape)
df.sample(10)
# Out:
# (4123, 9)
#       Year           Country  GDP per capita (current US$)  \
# 1192  2018           Estonia                  23165.849479
# 1313  2006  French Polynesia                  21382.235713
# 2686  2011       New Zealand                  38387.627078
# 1532  2016         Guatemala                   4173.281349
# 1047  2006          Dominica                   5677.051175
# 2368  2016  Marshall Islands                   4153.117176
# 3642  2017          Tanzania                    975.904663
# 3795  2018      Turkmenistan                   6721.349540
# 1939  2005          Kiribati                   1142.335850
# 2772  2021   North Macedonia                   6778.562878
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1192                                78.243902          1321977.0          EST
# 1313                                79.842000           274901.0          PYF
# ...

# %%
df["Year"].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df_filtered = df[df["Year"] == 2010].dropna(subset=["Population, total", "GDP per capita (current US$)", "Region"])
print(df_filtered.shape)
df_filtered.sample(5)
# Out:
# (209, 9)
#       Year      Country  GDP per capita (current US$)  \
# 2571  2010      Myanmar                   1003.033455
# 3958  2010   Uzbekistan                   1742.349256
# 44    2010      Algeria                   4495.921476
# 1355  2010  Gambia, The                    796.631829
# 3407  2010        Spain                  30532.480508
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2571                                63.329000         49390988.0          MMR
# 3958                                69.235000         28562400.0          UZB
# 44                                  73.808000         35856344.0          DZA
# 1355                                60.717000          1937275.0          GMB
# 3407                                81.626829         46576897.0          ESP
#
#                           Region         Income Group    Lending Type
# 2571         East Asia & Pacific  Lower middle income             IDA
# ...

# %%
population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()

population_by_region
# Out:
#                        Region  Population, total
# 0         East Asia & Pacific       2.162379e+09
# 1       Europe & Central Asia       8.889814e+08
# 2  Latin America & Caribbean        5.886271e+08
# 3  Middle East & North Africa       3.979976e+08
# 4               North America       3.433972e+08
# 5                  South Asia       1.660546e+09
# 6         Sub-Saharan Africa        8.677708e+08

# %%
fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'},
    hole=0.3
)
# Update traces to show both number and percentage
fig.update_traces(textinfo='label+value+percent')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
gdp_by_region = df_filtered.groupby('Region').agg(
    {
        'GDP per capita (current US$)': 'mean'
    }
).reset_index()

gdp_by_region
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  14068.845158
# 1       Europe & Central Asia                  31303.467052
# 2  Latin America & Caribbean                   12172.214861
# 3  Middle East & North Africa                  15578.718956
# 4               North America                  66029.336876
# 5                  South Asia                   2059.989661
# 6         Sub-Saharan Africa                    2310.375822

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 10/09/2024 Homework Question 2
#
# Round the Average GDP for each region to 2 decimal points.
# Sort the bar according to GDP either in ascending order. Currently, it is ordered alphabetically.

# %%
# Group and compute mean GDP per region
gdp_avg = df.groupby("Region")["GDP per capita (current US$)"].mean().round(2).reset_index()

# Sort data by GDP
gdp_avg = gdp_avg.sort_values(by="GDP per capita (current US$)", ascending=True)

# Create bar chart
fig = px.bar(
    gdp_avg,
    x="Region",
    y="GDP per capita (current US$)",
    title="Average GDP per Capita by Region",
    labels={"GDP per capita (current US$)": "Avg GDP per Capita (US$)"},
)

# Layout adjustments
fig.update_layout(
    xaxis_title="Region",
    yaxis_title="Avg GDP per Capita (US$)",
    xaxis={'categoryorder': 'total ascending'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
# Short cut to comment out many lines of code:
# First hightlight the code block
# then, hold down CTL, then press +/


# data = {
#     'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
#     'Grade': ['A', 'B', 'A', 'A', 'B'],
#     'Score': [90, 85, 92, 88, 78]
# }

# df = pd.DataFrame(data)

# # Define the aggregate functions to be applied to the 'Score' column
# agg_functions = {
#     'Score': ['mean', 'max']
# }

# # Group by 'Gender' and 'Grade', then apply the aggregate functions
# grouped = df.groupby(['Gender', 'Grade']).aggregate(agg_functions)

# print(grouped)

# %%
df_2018 = df[df["Year"] == 2018]
print(df_2018.shape)
df_2018.sample(5)
# Out:
# (217, 9)
#       Year                   Country  GDP per capita (current US$)  \
# 1553  2018                    Guinea                    944.417269
# 2731  2018                     Niger                    568.599660
# 3149  2018     Sao Tome and Principe                   1815.605495
# 2788  2018  Northern Mariana Islands                  25862.754453
# 527   2018    British Virgin Islands                           NaN
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1553                                   59.349         12554864.0          GIN
# 2731                                   62.454         22577058.0          NER
# 3149                                   68.355           211344.0          STP
# 2788                                      NaN            50304.0          MNP
# 527                                    75.831            30335.0          VGB
#
#                           Region         Income Group    Lending Type
# ...

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', q1, "median", q3, 'max'],
     'GDP per capita (current US$)': ['min', 'mean', q1, "median", q3, 'max']
    }
)

df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                                min       mean
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                       \
#                                    q1   median         q3        max
# Region
# East Asia & Pacific         68.461500  72.1625  79.667823  84.934146
# ...

# %%
df_group.to_excel("by_region.xlsx")

# %%
df_group.to_csv("by_region.csv")

# %%
# df_group.rename(columns={"min":"Minimum","max":"Maximum"}, inplace=True)  Alternative

COLUMN_DICT = {
    "min":"Minimum",
    "max":"Maximum",
    "mean": "Average",
    "q1": "1st Quartile",
    "q3": "3rd quartile"
}

df_group = df_group.rename(columns=COLUMN_DICT)
df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                            Minimum    Average
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                           \
#                            1st Quartile   median 3rd quartile    Maximum
# Region
# East Asia & Pacific           68.461500  72.1625    79.667823  84.934146
# ...

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    Minimum=('Life expectancy at birth, total (years)', 'min'),
    Average=('Life expectancy at birth, total (years)', 'mean'),
    percentile_25=('Life expectancy at birth, total (years)', q1)
)

df_group
# Out:
#                               Minimum    Average  percentile_25
# Region
# East Asia & Pacific         63.234000  73.848374      68.461500
# Europe & Central Asia       68.796000  78.131777      75.013707
# Latin America & Caribbean   64.019000  74.797838      73.127500
# Middle East & North Africa  63.038000  75.545677      72.794000
# North America               78.639024  80.435976      79.732012
# South Asia                  63.081000  71.088625      68.354750
# Sub-Saharan Africa          52.554000  62.542100      60.020750

# %% [markdown]
# ## 10/09/2024 Homework question 3
#
# Group the dataset by Region and Income Group, calculate the average, min, and max of GDP per Capita & life Expentancy, total, average, min, and max of population, then save the result to Excel.

# %%
# Initialize an empty list to store grouped data
grouped_data = []

# Loop through each unique combination of Region and Income Group
for region in df["Region"].unique():
    for income_group in df["Income Group"].unique():
        # Filter the data for the current combination
        df_filtered = df[(df["Region"] == region) & (df["Income Group"] == income_group)]

        if not df_filtered.empty:
            # Calculate required statistics
            avg_gdp = df_filtered["GDP per capita (current US$)"].mean()
            min_gdp = df_filtered["GDP per capita (current US$)"].min()
            max_gdp = df_filtered["GDP per capita (current US$)"].max()

            avg_life_exp = df_filtered["Life expectancy at birth, total (years)"].mean()
            min_life_exp = df_filtered["Life expectancy at birth, total (years)"].min()
            max_life_exp = df_filtered["Life expectancy at birth, total (years)"].max()

            avg_population = df_filtered["Population, total"].mean()
            min_population = df_filtered["Population, total"].min()
            max_population = df_filtered["Population, total"].max()

            # Append calculated values to the grouped_data list
            grouped_data.append([
                region, income_group, avg_gdp, min_gdp, max_gdp,
                avg_life_exp, min_life_exp, max_life_exp,
                avg_population, min_population, max_population
            ])

# Create a new DataFrame from the grouped data
df_grouped = pd.DataFrame(grouped_data, columns=[
    "Region", "Income Group",
    "Avg GDP per capita", "Min GDP per capita", "Max GDP per capita",
    "Avg Life Expectancy", "Min Life Expectancy", "Max Life Expectancy",
    "Avg Population", "Min Population", "Max Population"
])

# Round the results to 2 decimal places
df_grouped = df_grouped.round(2)

# Save the grouped data to Excel
df_grouped.to_excel("Grouped_Region_Income_Statistics.xlsx", index=False)

print("Grouped data saved to 'Grouped_Region_Income_Statistics.xlsx'.")
# Out:
# Grouped data saved to 'Grouped_Region_Income_Statistics.xlsx'.
